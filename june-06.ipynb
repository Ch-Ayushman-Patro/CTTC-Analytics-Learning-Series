# %% [markdown]
# # List

# %%
l1 = [20, 5, 67, 88, 90, 100, 45, 78, 34, 25]
l1
# Out:
# [20, 5, 67, 88, 90, 100, 45, 78, 34, 25]

# %%
id(l1)
# Out:
# 2719352305216

# %%
type(l1)
# Out:
# list

# %% [markdown]
# **List Slicing**

# %%
l3 = [2, 3, 4, 70, 'string', 77, 88, 100]
l3[3:6]
# Out:
# [70, 'string', 77]

# %%
l3[3:]
# Out:
# [70, 'string', 77, 88, 100]

# %%
l3[0:3]
# Out:
# [2, 3, 4]

# %%
l3[:3]
# Out:
# [2, 3, 4]

# %%
l3[::-1]
# Out:
# [100, 88, 77, 'string', 70, 4, 3, 2]

# %% [markdown]
# **List Functions**

# %%
l2 = l1.copy()
l2
# Out:
# [20, 5, 67, 88, 90, 100, 45, 78, 34, 25]

# %%
l1.append(48)
l1
# Out:
# [20, 5, 67, 88, 90, 100, 45, 78, 34, 25, 48]

# %%
l1.insert(2, 99)
l1
# Out:
# [20, 5, 99, 67, 88, 90, 100, 45, 78, 34, 25, 48]

# %%
l1.extend([120,24,10,77])
l1
# Out:
# [20, 5, 99, 67, 88, 90, 100, 45, 78, 34, 25, 48, 120, 24, 10, 77]

# %%
l3.remove(70)
l3
# Out:
# [2, 3, 4, 'string', 77, 88, 100]

# %%
l3.pop(2)
# Out:
# 4

# %%
l3
# Out:
# [2, 3, 'string', 77, 88, 100]

# %%
l3.clear()
l3
# Out:
# []

# %%
l4 = [2,2,2,2,3,3,5,5,6,7,9]
l4
# Out:
# [2, 2, 2, 2, 3, 3, 5, 5, 6, 7, 9]

# %%
l4.count(2)
# Out:
# 4

# %%
l4.index(3)
# Out:
# 4

# %%
l5 = [78, 2, 55, 16, 99, 33, 7]
l5
# Out:
# [78, 2, 55, 16, 99, 33, 7]

# %%
l5.reverse()
l5
# Out:
# [7, 33, 99, 16, 55, 2, 78]

# %%
l5.sort()
l5
# Out:
# [2, 7, 16, 33, 55, 78, 99]

# %%
sorted(l5)
# Out:
# [2, 7, 16, 33, 55, 78, 99]

# %%
l5.sort(reverse = True)
l5
# Out:
# [99, 78, 55, 33, 16, 7, 2]

# %% [markdown]
# **List Repitition**

# %%
l5*2
# Out:
# [99, 78, 55, 33, 16, 7, 2, 99, 78, 55, 33, 16, 7, 2]

# %% [markdown]
# **List Concatenation**

# %%
l6 = [9, 6.5, 2.3, 66]
l6
# Out:
# [9, 6.5, 2.3, 66]

# %%
l5+l6
# Out:
# [99, 78, 55, 33, 16, 7, 2, 9, 6.5, 2.3, 66]

# %% [markdown]
# # Tuple

# %%
t1 = (6, 7.5, 'tiger', 77, 98)
t1
# Out:
# (6, 7.5, 'tiger', 77, 98)

# %%
id(t1)
# Out:
# 2719351645952

# %%
type(t1)
# Out:
# tuple

# %% [markdown]
# **Tuple Functions**

# %%
t1.index('tiger')
# Out:
# 2

# %%
t2 = (5, 5, 99, 'tiger', 4)
t2
# Out:
# (5, 5, 99, 'tiger', 4)

# %%
t2.count(5)
# Out:
# 2

# %% [markdown]
# **Tuple Concatenation**

# %%
t1+t2
# Out:
# (6, 7.5, 'tiger', 77, 98, 5, 5, 99, 'tiger', 4)

# %% [markdown]
# **Tuple Repitition**

# %%
t1*2
# Out:
# (6, 7.5, 'tiger', 77, 98, 6, 7.5, 'tiger', 77, 98)

# %% [markdown]
# # Set

# %%
s1 = {26, 77, 89, 85, 85}
s1
# Out:
# {26, 77, 85, 89}

# %%
id(s1)
# Out:
# 2719351911168

# %%
type(s1)
# Out:
# set

# %% [markdown]
# **Set Functions**

# %%
s1.add(45)
s1
# Out:
# {26, 45, 77, 85, 89}

# %%
s2 = s1.copy()
s2
# Out:
# {26, 45, 77, 85, 89}

# %%
s3 = {2, 3, 4, 5, 6, 7}
s3
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
s4 = {4, 9, 8}
s4
# Out:
# {4, 8, 9}

# %%
s3.union(s4)
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9}

# %%
s3|s4
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9}

# %%
s3.intersection(s4)
# Out:
# {4}

# %%
s3&s4
# Out:
# {4}

# %%
s3.difference(s4)
# Out:
# {2, 3, 5, 6, 7}

# %%
s3-s4
# Out:
# {2, 3, 5, 6, 7}

# %%
s3.symmetric_difference(s4)
# Out:
# {2, 3, 5, 6, 7, 8, 9}

# %%
s3^s4
# Out:
# {2, 3, 5, 6, 7, 8, 9}

# %%
s5 = {2, 3, 4, 5, 6, 7}
s5
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
s6 = {4, 5}
s6
# Out:
# {4, 5}

# %%
s6.issubset(s5)
# Out:
# True

# %%
s5.issuperset(s6)
# Out:
# True

# %%
#disjoint

# %%
s5.pop()
# Out:
# 2

# %%
s5
# Out:
# {3, 4, 5, 6, 7}

# %%
s5.remove(5)
s5
# Out:
# {3, 4, 6, 7}

# %% [markdown]
# # Dictionary

# %%
d1 = {'Name':'Ashok', 'Roll':5, 'Course':'DS'}
d1
# Out:
# {'Name': 'Ashok', 'Roll': 5, 'Course': 'DS'}

# %%
id(d1)
# Out:
# 2719353095296

# %%
type(d1)
# Out:
# dict

# %% [markdown]
# **Dictionary Functions**

# %%
d1.update({'Marks':100})
d1
# Out:
# {'Name': 'Ashok', 'Roll': 5, 'Course': 'DS', 'Marks': 100}

# %%
d1.update({'Course':'DA'})
d1
# Out:
# {'Name': 'Ashok', 'Roll': 5, 'Course': 'DA', 'Marks': 100}

# %%
d1.popitem()
# Out:
# ('Marks', 100)

# %%
d1
# Out:
# {'Name': 'Ashok', 'Roll': 5, 'Course': 'DA'}

# %%
d1.pop('Roll')
# Out:
# 5

# %%
d1
# Out:
# {'Name': 'Ashok', 'Course': 'DA'}

# %%
d1.keys()
# Out:
# dict_keys(['Name', 'Course'])

# %%
d1.values()
# Out:
# dict_values(['Ashok', 'DA'])

# %%
d1.items()
# Out:
# dict_items([('Name', 'Ashok'), ('Course', 'DA')])

# %% [markdown]
# # Operators

# %% [markdown]
# **Artithmetic Operators :** +, -, *, /, //, %, **

# %%
a = 10
b = 7

# %%
a+b #Addition
# Out:
# 17

# %%
a-b #Substraction
# Out:
# 3

# %%
a*b #Multiplication
# Out:
# 70

# %%
a/b #Division
# Out:
# 1.4285714285714286

# %%
a//b #Floor Division
# Out:
# 1

# %%
a%b #Modulo
# Out:
# 3

# %%
a**b #Power
# Out:
# 10000000

# %% [markdown]
# **Assignement Operator :** =, +=, -=, *=, /=

# %%
a = 17
a
# Out:
# 17

# %%
a+=7
a
# Out:
# 24

# %%
a-=7
a
# Out:
# 17

# %%
a*=7
a
# Out:
# 119

# %%
a/=7
a
# Out:
# 17.0

# %%
a//=3
a
# Out:
# 5.0

# %%
a%=3
a
# Out:
# 2.0

# %%
a**=3
a
# Out:
# 8.0

# %% [markdown]
# **Comparision Operators :** ==, !=, >, >=, <, <=

# %%
a = 10
b = 7

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a > b
# Out:
# True

# %%
a >= b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a <= b
# Out:
# False

# %% [markdown]
# **Logical Operators :** and, or, not

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# **Identity Operators :** is, is not

# %%
a = 10
b = 7

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %% [markdown]
# **Membership Operators :** in, not in

# %%
a = 'apple'
b = 'a'
c = 'x'

# %%
b in a
# Out:
# True

# %%
b not in a
# Out:
# False

# %%
c in a
# Out:
# False

# %%
c not in a
# Out:
# True

# %% [markdown]
# # Typecasting

# %%
v1 = '10.25'
v1
# Out:
# '10.25'

# %%
type(v1)
# Out:
# str

# %%
v2 = float(v1)
v2
# Out:
# 10.25

# %%
type(v2)
# Out:
# float

# %%
v3 = "50"
v3
# Out:
# '50'

# %%
type(v3)
# Out:
# str

# %%
v4 = int(v3)
v4
# Out:
# 50

# %%
type(v4)
# Out:
# int

# %%
v5 = "Ashok"
v5
# Out:
# 'Ashok'

# %%
type(v5)
# Out:
# str

# %%
v6 = list(v5)
v6
# Out:
# ['A', 's', 'h', 'o', 'k']

# %%
type(v6)
# Out:
# list

# %%
v7 = tuple(v5)
v7
# Out:
# ('A', 's', 'h', 'o', 'k')

# %%
type(v7)
# Out:
# tuple

# %% [markdown]
# # Built-in Functions

# %%
l = [11,7,10,9,4]
l
# Out:
# [11, 7, 10, 9, 4]

# %%
id(l) #Returns Memory Address
# Out:
# 2719352474176

# %%
type(l) #Returns Datatype
# Out:
# list

# %%
max(l)
# Out:
# 11

# %%
min(l)
# Out:
# 4

# %%
sum(l)
# Out:
# 41

# %% [markdown]
# # Condtional Statements

# %% [markdown]
# + if
# + if-else
# + Nested if
# + if-elif-else

# %%
if 10>7:
    print("Correct")
# Out:
# Correct

# %%
n = int(input("Enter a number: "))
if n>10:
    print("Greater than 10")
# Out:
# Enter a number:  11
# Greater than 10

# %%
n = int(input("Enter a number: "))
if n>10:
    print("Greater than 10")
# Out:
# Enter a number:  7

# %%
n = int(input("Enter a number: "))
if n>10:
    print("Greater than 10")
else:
    print("Lesser than 10")
# Out:
# Enter a number:  7
# Lesser than 10

# %%
#WAP to check whether a number is even or odd
if int(input())%2==0: print("Even")
else: print("Odd")
# Out:
#  10
# Even
