# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # Keywords

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
import keyword as kw
kw.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# **"kw.iskeyword()" is used to check whether it is a keyword or not**

# %%
kw.iskeyword('as')
# Out:
# True

# %%
kw.iskeyword('Ashok')
# Out:
# False

# %% [markdown]
# # Identifiers

# %%
'Ashok'.isidentifier()
# Out:
# True

# %%
'0Ashok'.isidentifier()
# Out:
# False

# %%
'Ashok@'.isidentifier()
# Out:
# False

# %% [markdown]
# # Variables

# %%
v1 = 10
id(v1)
# Out:
# 140723493987400

# %%
v1 = 7
id(v1)
# Out:
# 140723493987304

# %%
v2 = 11
print(v2)
# Out:
# 11

# %% [markdown]
# **Single Variable Assignment**

# %%
a = 10
b = 5.0
c = "Ashok"
print(a, b, c)
# Out:
# 10 5.0 Ashok

# %% [markdown]
# **Multiple Variable Assignment**

# %%
a, b, c = 10, 5.0, "Ashok"
print(a, b, c)
# Out:
# 10 5.0 Ashok

# %% [markdown]
# #

# %%
print(print("Hello World"))
# Out:
# Hello World
# None

# %%
print(print(print("Hello World")))
# Out:
# Hello World
# None
# None

# %% [markdown]
# # Input & Output Statements

# %%
n1 = input("Enter a number: ")
print(n1)
# Out:
# Enter a number:  10
# 10

# %%
name = input("Enter name: ")
print("Nice to meet you, "+name)
# Out:
# Enter name:  Ashok
# Nice to meet you, Ashok

# %% [markdown]
# # Datatypes

# %%
a = 10
print(a)
type(a)
# Out:
# 10
# int

# %%
b = 4.5
print(b)
type(b)
# Out:
# 4.5
# float

# %%
c = 10 + 7j
print(c)
type(c)
# Out:
# (10+7j)
# complex

# %%
d = "Ashok"
print(d)
type(d)
# Out:
# Ashok
# str

# %%
e = """Ashok
     Swain"""
print(e)
type(e)
# Out:
# Ashok
#      Swain
# str

# %% [markdown]
# # String Indexing & Slicing

# %%
s1 = "The Apple is tasty"
s1
# Out:
# 'The Apple is tasty'

# %%
s1[0]
# Out:
# 'T'

# %%
s1[4]
# Out:
# 'A'

# %%
s1[4:]
# Out:
# 'Apple is tasty'

# %%
s1[:9]
# Out:
# 'The Apple'

# %%
s1[4:9]
# Out:
# 'Apple'

# %%
s1[4:9:2]
# Out:
# 'Ape'

# %%
s1[:3]
# Out:
# 'The'

# %%
s1[-1]
# Out:
# 'y'

# %%
s1[-3:]
# Out:
# 'sty'

# %%
s1[-3:-1]
# Out:
# 'st'

# %%
s1[-1:-3]
# Out:
# ''

# %%
s1[:-3]
# Out:
# 'The Apple is ta'

# %%
s1[-5:]
# Out:
# 'tasty'

# %%
s1[::-1]
# Out:
# 'ytsat si elppA ehT'

# %%
s1[10:12]
# Out:
# 'is'

# %%
s1[-8:-6]
# Out:
# 'is'

# %% [markdown]
# # String Functions

# %%
s2 = "heLlo wOrlD"
s2
# Out:
# 'heLlo wOrlD'

# %%
s2.capitalize()
# Out:
# 'Hello world'

# %%
s2.title()
# Out:
# 'Hello World'

# %%
s2.upper()
# Out:
# 'HELLO WORLD'

# %%
s2.lower()
# Out:
# 'hello world'

# %%
s2.casefold()
# Out:
# 'hello world'

# %%
s2.center(17)
# Out:
# '   heLlo wOrlD   '

# %%
s2.center(17, '_')
# Out:
# '___heLlo wOrlD___'

# %%
s2.center(17, '0')
# Out:
# '000heLlo wOrlD000'

# %%
s3 = "   Ashok Swain  "
s3.strip()
# Out:
# 'Ashok Swain'

# %%
s3.lstrip()
# Out:
# 'Ashok Swain  '

# %%
s3.rstrip()
# Out:
# '   Ashok Swain'

# %%
s2.center(17).strip()
# Out:
# 'heLlo wOrlD'

# %%
s2.index('e')
# Out:
# 1

# %%
s2.count('l')
# Out:
# 2

# %%
"Ashok".isalpha()
# Out:
# True

# %%
"Ashok".isdigit()
# Out:
# False

# %%
"10".isdigit()
# Out:
# True

# %%
"10".isnumeric()
# Out:
# True

# %%
"10".isalpha()
# Out:
# False

# %%
"Ashok".isalnum()
# Out:
# True

# %%
"10".isalnum()
# Out:
# True

# %%
"Ashok".islower()
# Out:
# False

# %%
"ashok".islower()
# Out:
# True

# %%
"Ashok".isupper()
# Out:
# False

# %%
"ASHOK".isupper()
# Out:
# True

# %%
'-'.join(['Ashok', 'Swain'])
# Out:
# 'Ashok-Swain'

# %%
'Ashok-Swain'.split('-')
# Out:
# ['Ashok', 'Swain']

# %% [markdown]
# # List

# %%
l1 = [10, 7.0, 'Ashok', True]
l1
# Out:
# [10, 7.0, 'Ashok', True]

# %%
id(l1)
# Out:
# 2265229263808

# %%
print(type(l1))
# Out:
# <class 'list'>
