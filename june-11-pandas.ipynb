# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %% [markdown]
# # Series

# %%
s1 = pd.Series(['a', 'b', 'c', 'd', 'e'])
s1
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
s2 = pd.Series(['a', 'b', 'c', 'd', 'e'], index = [10, 20, 30, 40, 50])
s2
# Out:
# 10    a
# 20    b
# 30    c
# 40    d
# 50    e
# dtype: object

# %%
s2[20]
# Out:
# 'b'

# %%
d1 = {'a':1, 'b':2, 'c':3}
d1
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
s3 = pd.Series(d1)
s3
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s4 = pd.Series(d1, index = ['e', 'a', 'g', 'b'])
s4
# Out:
# e    NaN
# a    1.0
# g    NaN
# b    2.0
# dtype: float64

# %%
s5 = pd.Series({'a':1, 'b':2, 'c':3, 'd':4})
s5
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s5['c']
# Out:
# 3

# %%
s5[2]
# Out:
# 3

# %% [markdown]
# # Dataframe

# %%
d1 = {'Name' : ['Ch Ayushman Patro', 'Anushka Palo', 'Ashok Swain', 'Lipsa Rani Gouda', 'Ayush Pattnaik'],
      'Course' : ['Data Science', 'Data Analytics', 'Archeology', 'Data Analytics', 'Android Development'],
      'Marks' : [71, 98, 96, 97, 90]}
d1
# Out:
# {'Name': ['Ch Ayushman Patro',
#   'Anushka Palo',
#   'Ashok Swain',
#   'Lipsa Rani Gouda',
#   'Ayush Pattnaik'],
#  'Course': ['Data Science',
#   'Data Analytics',
#   'Archeology',
#   'Data Analytics',
#   'Android Development'],
#  'Marks': [71, 98, 96, 97, 90]}

# %%
df1 = pd.DataFrame(d1)
df1
# Out:
#                 Name               Course  Marks
# 0  Ch Ayushman Patro         Data Science     71
# 1       Anushka Palo       Data Analytics     98
# 2        Ashok Swain           Archeology     96
# 3   Lipsa Rani Gouda       Data Analytics     97
# 4     Ayush Pattnaik  Android Development     90

# %%
df1.head(2)
# Out:
#                 Name          Course  Marks
# 0  Ch Ayushman Patro    Data Science     71
# 1       Anushka Palo  Data Analytics     98

# %%
df1.tail(2)
# Out:
#                Name               Course  Marks
# 3  Lipsa Rani Gouda       Data Analytics     97
# 4    Ayush Pattnaik  Android Development     90

# %%
df1.rename(columns = {'Name' : 'Student Name'}, inplace = True)
df1
# Out:
#         Student Name               Course  Marks
# 0  Ch Ayushman Patro         Data Science     71
# 1       Anushka Palo       Data Analytics     98
# 2        Ashok Swain           Archeology     96
# 3   Lipsa Rani Gouda       Data Analytics     97
# 4     Ayush Pattnaik  Android Development     90

# %%
df1.set_index('Student Name', inplace = True)
df1
# Out:
#                                 Course  Marks
# Student Name
# Ch Ayushman Patro         Data Science     71
# Anushka Palo            Data Analytics     98
# Ashok Swain                 Archeology     96
# Lipsa Rani Gouda        Data Analytics     97
# Ayush Pattnaik     Android Development     90
