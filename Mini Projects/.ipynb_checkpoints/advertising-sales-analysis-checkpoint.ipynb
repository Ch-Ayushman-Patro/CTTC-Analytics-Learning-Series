# %% [markdown]
# # Importing of Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv(r".\Datasets\advertising.csv")
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# # Data Cleaning

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# # Data Analysis

# %%
plt.figure(figsize = (13,5))
sns.distplot(df.TV)
plt.title("Distribution of TV Advertisements")
plt.show()

# %%
plt.figure(figsize = (13,5))
sns.distplot(df.Radio)
plt.title("Distribution of Radio Advertisements")
plt.show()

# %%
plt.figure(figsize = (13,5))
sns.distplot(df.Newspaper)
plt.title("Distribution of Newspaper Advertisements")
plt.show()

# %%
plt.figure(figsize = (13,5))
sns.lineplot(data = df, x = 'TV', y = 'Sales')
plt.title('Relation between TV Advertising and Sales')
plt.show()

# %%
plt.figure(figsize = (13,5))
sns.lineplot(data = df, x = 'Radio', y = 'Sales')
plt.title('Relation between Radio Advertising and Sales')
plt.show()

# %%
plt.figure(figsize = (13,5))
sns.scatterplot(data = df, x = 'Newspaper', y = 'Sales')
plt.title('Relation between Newspaper Advertising and Sales')
plt.show()

# %%
df_corr = df.corr()
df_corr
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
plt.figure(figsize = (13,5))
sns.heatmap(df_corr, annot = True, cmap = 'coolwarm')
plt.yticks(rotation = 0)
plt.title('Heatmap Matrix of Co-relation among "Different Channels of Advertising" and "Sales" ')
plt.show()

# %% [markdown]
# # Input & Output Creation

# %%
ip = df.drop(['Sales'], axis = 1)
ip
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
op = df['Sales']
op
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# # Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(ip, op, train_size = 0.7)

# %%
df.shape, x_train.shape, x_test.shape
# Out:
# ((200, 4), (140, 3), (60, 3))

# %% [markdown]
# # Standard Scaler Transform

# %%
sc = StandardScaler()
sc
# Out:
# StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
x_train
# Out:
# array([[-1.58003378e+00,  2.59300569e-01, -1.30956746e+00],
#        [ 1.61417574e+00,  1.32048994e+00,  1.92785636e+00],
#        [ 1.64964153e+00, -1.29218516e+00, -1.01230043e+00],
#        [ 8.46512918e-01,  6.62283876e-01,  3.53270023e-01],
#        [-4.19959121e-01, -6.07113542e-01,  6.52925813e-02],
#        [ 5.71130022e-02,  1.20631134e+00,  1.31009830e+00],
#        [-1.16702890e+00,  1.07198357e+00,  6.87695440e-01],
#        [-8.36396178e-01, -4.25771054e-01, -8.07929340e-01],
#        [ 1.52951545e+00, -8.89201857e-01, -4.13121556e-01],
#        [ 1.63820095e+00,  1.27347523e+00,  9.71028084e-01],
#        [ 1.32930533e+00,  3.66762784e-01, -6.68585416e-01],
#        [-1.69410452e-01, -3.31741616e-01,  1.99991707e-01],
#        [-1.23910454e+00, -1.31905072e+00, -7.66126163e-01],
#        [-1.59261842e+00,  3.19748065e-01,  5.15837934e-01],
#        [-1.39664948e-01, -1.23845406e+00, -9.75142048e-01],
#        [ 5.84523671e-01, -2.63858118e-03, -7.47546973e-01],
#        [ 1.07074826e+00, -1.07726073e+00, -1.00301083e+00],
#        [-9.19912401e-01, -1.17800656e+00, -2.83067228e-01],
#        [ 1.82067442,  0.90358348,  3.14714139],
#        [ 1.1249066 , -1.29866616,  0.2590277 ],
#        [ 0.21278694, -0.89514837, -0.61191909],
#        [-1.50819354,  1.08824417, -0.98647133],
#        [-0.10805299, -1.43545185, -0.2057781 ],
#        [-0.46208326,  1.19767272,  1.44586192],
#        [ 0.81635938,  0.06235148, -1.22564325],
#        [-1.77248697, -0.78571981, -1.14892773],
#        [ 0.97001836, -0.49846986,  0.84567579],
#        [ 0.19926495, -0.14966634,  0.73285885],
#        [ 0.80037885,  0.10338719, -0.81498958],
#        [-1.16522671, -1.44229114, -0.44043734],
#        [-0.06625775,  0.42483356, -0.83755297],
#        [-1.33732476,  1.23186915, -1.14441505],
#        [ 0.80160812,  1.36181555,  0.11913469],
#        [ 0.76718851,  0.43851213, -0.98647133],
#        [ 0.99829161,  0.6300121 ,  1.94225646],
#        [ 1.0597552 , -1.34654115,  2.42060029],
#        [-1.27340263,  0.1854586 , -0.47653876],
#        [ 1.78625481,  0.31540501, -1.32492216],
#        [ 0.76841779,  1.81320834,  0.29512912],
#        [ 1.67193254, -0.85411266, -1.11733899],
#        [-1.0005043 , -0.77888053,  0.25451502],
#        [ 0.86184244,  0.31540501,  1.00361951],
#        [ 0.85323754,  0.71208352,  1.25632946],
#        [-0.23220944, -1.18923761,  0.00631775],
#        [ 0.71924691, -1.22343403, -0.53069089],
#        [-1.71594047,  1.76533335,  1.97835788],
#        [ 0.75366652, -0.1701842 , -0.92329385],
#        [-1.0570508 , -0.71732697, -0.58033035],
#        [-0.34161463,  0.37011929, -0.76535013],
#        [-0.7694012 ,  0.86938706,  0.81859973],
#        [ 0.93068166, -1.414934  , -0.70217264],
#        [-0.89724547, -0.19070205,  0.06046988],
#        [ 0.55206595, -0.32064846,  1.55867886],
#        [ 0.60615391, -1.33970187, -1.13990237],
#        [ 1.12613587,  1.25922628, -0.57130499],
#        [-0.64647403, -1.48332684, -1.07221221],
#        [-0.01216979,  0.05551219, -0.54422892],
#        [ 0.48691455, -0.40271988, -0.59838106],
#        [-1.59178402, -0.09495207,  0.86823918],
#        [ 0.32956776, -0.04023779,  0.0153431 ],
#        [-0.50264923, -0.62157698, -0.91426849],
#        [ 0.22753821,  1.29342271, -1.24369396],
#        [-1.72700391,  1.08140488,  0.87726454],
#        [-1.66185251, -1.55171969, -0.25090488],
#        [-0.21131182,  1.34813698, -0.10198651],
#        [ 1.29700465, -0.12230921, -0.05234706],
#        [-0.98206522,  1.46440482,  0.20036289],
#        [-1.22914885,  1.63538694, -1.02257276],
#        [ 0.35292393,  0.70524423,  0.34025589],
#        [-1.66062324, -0.49163058,  0.83213776]])

# %% [markdown]
# # Implementation of ML Model

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Prediction

# %%
ycap = lr.predict(x_test)
ycap
# Out:
# array([ 9.80284677, 18.34699355, 11.98047665, 13.11458587, 16.50603982,
#        23.91708508, 18.94696992, 10.70628359, 25.31559016, 18.34175338,
#        14.67815817,  9.80792456, 12.30676303, 14.99988973, 19.04934853,
#         5.50645232, 18.94135778, 15.88349915, 19.05770872,  7.31875308,
#        15.50839639, 10.83840445, 21.15146085, 19.44081233, 20.95703827,
#        18.04496822,  9.46093306, 24.01489915, 21.73802841, 21.58073837,
#         9.20165024, 19.76541384, 20.38146134, 12.13308633, 16.52632169,
#        10.05468841, 18.38814095,  9.00250244, 14.12834274, 12.99569373,
#        17.20087808, 10.63725616, 17.29602445, 15.78088712, 22.4812958 ,
#         9.66385423, 15.17269575, 16.76902416,  7.56243463, 16.64504671,
#        11.7499943 , 18.28756176,  8.84395641,  4.81461453, 16.36079244,
#        21.05433622, 12.94086232, 12.00902938, 17.98245904,  6.59124973])

# %%
pdf = pd.DataFrame({'y':list(y_test),
                    'prediction':ycap})
pdf
# Out:
#        y  prediction
# 0   13.2    9.802847
# 1   18.4   18.346994
# 2   11.6   11.980477
# 3   13.2   13.114586
# 4   17.2   16.506040
# 5   24.2   23.917085
# 6   18.3   18.946970
# 7   10.4   10.706284
# 8   23.8   25.315590
# 9   17.3   18.341753
# 10  17.6   14.678158
# 11   9.5    9.807925
# 12  10.3   12.306763
# 13  16.0   14.999890
# 14  17.4   19.049349
# 15   3.2    5.506452
# 16  19.8   18.941358
# 17  17.5   15.883499
# 18  17.0   19.057709
# 19   8.1    7.318753
# 20  15.0   15.508396
# 21  10.8   10.838404
# 22  21.7   21.151461
# 23  18.4   19.440812
# 24  19.7   20.957038
# 25  16.9   18.044968
# 26  10.1    9.460933
# 27  20.7   24.014899
# 28  23.8   21.738028
# 29  20.0   21.580738
# 30   9.7    9.201650
# 31  18.0   19.765414
# 32  19.4   20.381461
# 33  11.0   12.133086
# 34  17.2   16.526322
# 35   7.2   10.054688
# 36  20.9   18.388141
# 37   9.7    9.002502
# 38  14.2   14.128343
# 39  13.3   12.995694
# 40  16.6   17.200878
# 41  11.3   10.637256
# 42  20.2   17.296024
# 43  16.7   15.780887
# 44  23.2   22.481296
# 45  11.9    9.663854
# 46  14.6   15.172696
# 47  19.7   16.769024
# 48   7.0    7.562435
# 49  16.1   16.645047
# 50  11.5   11.749994
# 51  19.6   18.287562
# 52   6.6    8.843956
# 53   5.3    4.814615
# 54  16.0   16.360792
# 55  17.6   21.054336
# 56  13.6   12.940862
# 57  11.6   12.009029
# 58  17.1   17.982459
# 59   5.6    6.591250

# %% [markdown]
# # Accuracy & Error Scores

# %%
mse = mean_squared_error(y_test, ycap)
print("Mean Squared Error: ", mse)
# Out:
# Mean Squared Error:  2.2741040527680023

# %%
r2 = r2_score(y_test, ycap)
print("R2 Score:", r2)
print("Accuracy:", r2*100)
# Out:
# R2 Score: 0.9093709137609027
# Accuracy: 90.93709137609028

# %%
sns.kdeplot(df["Sales"], label = "Actual Value")
sns.kdeplot(y_test, label = "Testing Values")
sns.kdeplot(ycap, label = "Predicted Values")
plt.legend()
plt.show()
