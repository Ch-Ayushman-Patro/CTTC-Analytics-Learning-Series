# %% [markdown]
# # Machine Learning Procedures
#
# - Reading Data
# - Data Cleaning
# - Data Analysis
# - Encoding
# - ip / op creation
# - Train Test Split
# - Standard Scaler Transform
# - ML Model
# - Prediction
# - Accuracy

# %% [markdown]
# # Supervised Learning
#
# - Regression (O/P - Continuos)
# - Classification (O/P - Categorial)

# %% [markdown]
# # Regression
#
# - Linear Regression
# - Polynomial Regression
# - Lasso Regression
# - Ridge Regression

# %% [markdown]
# # Classification
#
# - Logistic Regression
# - KNN ( K-Nearest-Neighbour)
# - Naive Bayes
# - SVM ( Support Vector Machine)
# - Decision Tree
# - Random Forest

# %% [markdown]
# # Linear Regression
#
# Linear Regression model assumes a linear relationship between the input variables and output variables
#
# **y-cap = m x + c**
#
# **e = y - y-cap**
